# %%
# !wget -O AirQuality.sqlite https://github.com/thousandoaks/Python4DS201/blob/main/data/AirQuality.sqlite?raw=true
# Out:
# --2022-12-17 11:54:25--  https://github.com/thousandoaks/Python4DS201/blob/main/data/AirQuality.sqlite?raw=true
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/thousandoaks/Python4DS201/raw/main/data/AirQuality.sqlite [following]
# --2022-12-17 11:54:25--  https://github.com/thousandoaks/Python4DS201/raw/main/data/AirQuality.sqlite
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/thousandoaks/Python4DS201/main/data/AirQuality.sqlite [following]
# --2022-12-17 11:54:25--  https://raw.githubusercontent.com/thousandoaks/Python4DS201/main/data/AirQuality.sqlite
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7741440 (7.4M) [application/octet-stream]
# Saving to: ‘AirQuality.sqlite’
#
# AirQuality.sqlite   100%[===================>]   7.38M  --.-KB/s    in 0.09s
#
# 2022-12-17 11:54:25 (84.3 MB/s) - ‘AirQuality.sqlite’ saved [7741440/7741440]

# %% [markdown]
# ### Embed the examples of kaggle learn sql tutorial

# %%
import sqlite3

# %%
con = sqlite3.connect('AirQuality.sqlite')
cursor = con.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('AirQuality',)]

# %%
con = sqlite3.connect('AirQuality.sqlite')
cursor = con.cursor()
cursor.execute("SELECT * FROM 'AirQuality' WHERE country = 'US'")

# %%
rows = cursor.fetchall()

# %%
rows
# Out:
# [(8132,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   1.3,
#   '2022-05-03 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8133,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.18,
#   '2022-04-30 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8134,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.32,
#   '2022-04-28 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8135,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.21,
#   '2022-04-29 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8136,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.6,
#   '2022-05-09 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8137,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.53,
#   '2022-05-19 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8138,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.43,
#   '2022-05-05 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8139,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-04-29 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8140,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.0,
#   '2022-04-29 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8141,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.16,
#   '2022-05-25 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8142,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.3,
#   '2022-05-13 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8143,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-11 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8144,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-22 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8145,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   2.1,
#   '2022-05-05 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8146,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.18,
#   '2022-05-05 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8147,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.09,
#   '2022-05-08 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8148,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.2,
#   '2022-05-04 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8149,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.18,
#   '2022-05-16 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8150,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.0,
#   '2022-04-29 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8151,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.13,
#   '2022-05-14 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8152,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-25 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8153,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.19,
#   '2022-05-05 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8154,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.0,
#   '2022-05-12 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8155,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.08,
#   '2022-04-29 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8156,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-11 21:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8157,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.25,
#   '2022-05-04 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8158,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.8,
#   '2022-05-16 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8159,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.5,
#   '2022-05-17 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8160,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.2,
#   '2022-04-04 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8161,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.09,
#   '2022-05-08 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8162,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.21,
#   '2022-05-12 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.76988,
#   -71.428489,
#   'POINT(41.76988 1)'),
#  (8163,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.06,
#   '2022-05-18 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8164,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.25,
#   '2022-05-05 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8165,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.09,
#   '2022-05-02 21:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8166,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.02,
#   '2022-05-21 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8167,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.05,
#   '2022-05-08 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8168,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.31,
#   '2022-05-13 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8169,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.1,
#   '2022-04-30 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8170,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.1,
#   '2022-04-27 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8171,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.22,
#   '2022-04-04 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8172,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.44,
#   '2022-05-26 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8173,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.13,
#   '2022-04-29 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8174,
#   'Elkhart-Prairie St.',
#   'Elkhart-Goshen',
#   'US',
#   'bc',
#   0.23,
#   '2020-06-11 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   41.656944,
#   -85.96833,
#   1.0,
#   'POINT(-85.96833 41.656944)'),
#  (8175,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   1.6,
#   '2022-04-29 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8176,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.18,
#   '2022-05-04 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8177,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.24,
#   '2022-05-05 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8178,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.27,
#   '2022-05-08 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8179,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.22,
#   '2022-05-15 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8180,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.16,
#   '2022-05-03 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8181,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-09 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8182,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.14,
#   '2022-05-01 23:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8183,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.6,
#   '2022-05-07 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8184,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-08 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8185,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.9,
#   '2022-05-10 06:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8186,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-11 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8187,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-09 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8188,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-04-30 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8189,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.07,
#   '2022-04-28 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8190,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-15 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8191,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.59,
#   '2022-04-28 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8192,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.28,
#   '2022-05-05 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8193,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.42,
#   '2022-04-07 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (8194,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.9,
#   '2022-05-09 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8195,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-02 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8196,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   1.21,
#   '2022-05-02 23:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8197,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.13,
#   '2022-05-18 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8198,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-04-29 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8199,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-02 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.829495,
#   -71.417457,
#   'POINT(41.829495 1)'),
#  (8200,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   1.04,
#   '2022-05-14 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8201,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.88,
#   '2022-05-04 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.829495,
#   -71.417457,
#   'POINT(41.829495 1)'),
#  (8202,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.0,
#   '2022-04-29 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8203,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.18,
#   '2022-05-20 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8204,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.6,
#   '2022-05-03 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8205,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.12,
#   '2022-05-02 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8206,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.05,
#   '2022-05-09 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8207,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.27,
#   '2022-04-25 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8208,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-16 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8209,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.51,
#   '2022-05-21 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8210,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.32,
#   '2022-04-29 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8211,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.8,
#   '2022-05-06 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8212,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.5,
#   '2022-05-11 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8213,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-15 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8214,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.61,
#   '2022-05-22 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8215,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   1.51,
#   '2022-05-19 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (8216,
#   'Indpls-Washington Pa',
#   'Indianapolis',
#   'US',
#   'bc',
#   0.56,
#   '2021-01-01 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.8108,
#   -86.1147,
#   'POINT(39.8108 1)'),
#  (8217,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.36,
#   '2022-05-08 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8218,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.36,
#   '2022-05-05 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8219,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.25,
#   '2022-05-22 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8220,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.2,
#   '2022-05-11 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8221,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.11,
#   '2022-05-07 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8222,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.34,
#   '2022-05-26 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8223,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.92,
#   '2022-05-06 21:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8224,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.11,
#   '2022-05-08 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8225,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-08 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8226,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.12,
#   '2022-05-07 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8227,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.06,
#   '2022-05-07 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8228,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.05,
#   '2022-05-07 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8229,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.28,
#   '2022-04-28 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8230,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.6,
#   '2022-05-21 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8231,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.13,
#   '2022-05-06 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8232,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.12,
#   '2022-05-14 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8233,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.17,
#   '2022-05-15 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8234,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.69,
#   '2022-05-21 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8235,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.5,
#   '2022-04-17 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8236,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.5,
#   '2022-04-28 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8237,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.28,
#   '2022-05-14 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8238,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.25,
#   '2022-05-04 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.829495,
#   -71.417457,
#   'POINT(41.829495 1)'),
#  (8239,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.3,
#   '2022-04-30 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8240,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.21,
#   '2022-05-09 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8241,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.15,
#   '2022-05-10 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8242,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-15 21:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8243,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.28,
#   '2022-04-27 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8244,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.08,
#   '2022-04-30 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8245,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.17,
#   '2022-05-07 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8246,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.25,
#   '2022-05-26 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8247,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.09,
#   '2022-05-07 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8248,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.38,
#   '2022-05-13 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8249,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.22,
#   '2022-05-11 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8250,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.13,
#   '2022-05-07 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8251,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.39,
#   '2022-05-13 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8252,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.06,
#   '2022-04-28 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8253,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-25 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8254,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.45,
#   '2022-05-12 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8255,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.41,
#   '2022-05-25 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (8256,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.14,
#   '2022-05-09 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8257,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.8,
#   '2022-04-30 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8258,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   2.2,
#   '2022-05-04 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8259,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.9,
#   '2022-05-04 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8260,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   2.2,
#   '2022-05-03 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8261,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   1.2,
#   '2022-04-29 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8262,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.07,
#   '2022-05-12 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8263,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.14,
#   '2022-05-13 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8264,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.32,
#   '2022-04-29 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8265,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.45,
#   '2022-05-14 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8266,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.0,
#   '2022-05-05 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8267,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.28,
#   '2022-05-24 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8268,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-02 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8269,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.3,
#   '2022-05-14 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8270,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.0,
#   '2022-05-05 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8271,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.82,
#   '2022-05-13 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8272,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   1.35,
#   '2022-05-05 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.76988,
#   -71.428489,
#   'POINT(41.76988 1)'),
#  (8273,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.89,
#   '2022-05-12 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (8274,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.7,
#   '2022-04-28 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8275,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.8,
#   '2022-05-06 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8276,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.21,
#   '2022-04-29 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8277,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.27,
#   '2022-05-08 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8278,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.21,
#   '2022-05-11 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8279,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.28,
#   '2022-05-08 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8280,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-06 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8281,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.09,
#   '2022-04-27 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8282,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.2,
#   '2022-04-11 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8283,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-06 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8284,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-07 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8285,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.07,
#   '2022-05-04 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8286,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.43,
#   '2022-05-05 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.76988,
#   -71.428489,
#   'POINT(41.76988 1)'),
#  (8287,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.48,
#   '2022-05-14 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8288,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.21,
#   '2022-05-12 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8289,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.6,
#   '2022-05-02 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8290,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-25 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8291,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.22,
#   '2022-05-03 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.829495,
#   -71.417457,
#   'POINT(41.829495 1)'),
#  (8292,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   1.26,
#   '2022-05-12 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8293,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.8,
#   '2022-05-10 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8294,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.8,
#   '2022-05-04 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8295,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   2.72,
#   '2022-05-19 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8296,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.25,
#   '2022-04-30 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8297,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.23,
#   '2022-05-10 06:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8298,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.11,
#   '2022-04-28 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8299,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.16,
#   '2022-05-07 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8300,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.09,
#   '2022-05-03 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8301,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-15 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8302,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   1.4,
#   '2022-05-14 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8303,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.11,
#   '2022-04-28 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8304,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.15,
#   '2022-05-06 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8305,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   1.0,
#   '2022-05-15 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8306,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.0,
#   '2022-05-15 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8307,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-21 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8308,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.27,
#   '2022-05-12 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8309,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.04,
#   '2022-05-07 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8310,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.08,
#   '2022-05-10 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8311,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.15,
#   '2022-04-29 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8312,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.11,
#   '2022-05-10 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8313,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.11,
#   '2022-05-07 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8314,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.15,
#   '2022-05-11 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8315,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-23 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8316,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.13,
#   '2022-05-09 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8317,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-10 06:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8318,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.5,
#   '2022-05-07 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8319,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.3,
#   '2022-04-30 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8320,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.37,
#   '2022-05-10 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8321,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.74,
#   '2022-05-11 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8322,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.32,
#   '2022-05-11 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8323,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.8,
#   '2022-04-13 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8324,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.31,
#   '2022-05-18 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8325,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-14 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8326,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.12,
#   '2022-05-15 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8327,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.06,
#   '2022-05-08 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8328,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.28,
#   '2022-05-13 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8329,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-04 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8330,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.11,
#   '2022-05-24 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8331,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.21,
#   '2022-05-13 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.76988,
#   -71.428489,
#   'POINT(41.76988 1)'),
#  (8332,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.9,
#   '2022-05-17 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8333,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.35,
#   '2022-05-22 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8334,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-06 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8335,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.7,
#   '2022-05-22 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8336,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.6,
#   '2022-05-05 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8337,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-12 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8338,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   1.1,
#   '2022-04-30 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8339,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.64,
#   '2022-05-09 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (8340,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.5,
#   '2022-04-27 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (8341,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.21,
#   '2022-05-10 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8342,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.06,
#   '2022-04-28 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8343,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.62,
#   '2022-05-04 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.829495,
#   -71.417457,
#   'POINT(41.829495 1)'),
#  (8344,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.72,
#   '2022-05-21 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8345,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.2,
#   '2022-04-04 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8346,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.3,
#   '2022-03-31 21:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8347,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-02 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (8348,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-09 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (8349,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.2,
#   '2022-05-12 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8350,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.06,
#   '2022-04-30 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8351,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-04 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8352,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.16,
#   '2022-05-14 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8353,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.3,
#   '2022-05-01 23:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (8354,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.12,
#   '2022-05-24 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8355,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.32,
#   '2022-05-06 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (8356,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.28,
#   '2022-05-09 21:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (8357,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.14,
#   '2022-05-07 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (8358,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.54,
#   '2022-05-24 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8359,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.6,
#   '2022-04-09 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8360,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.18,
#   '2022-05-07 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8361,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.55,
#   '2022-05-16 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (8362,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   1.29,
#   '2022-05-06 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.76988,
#   -71.428489,
#   'POINT(41.76988 1)'),
#  (8363,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.05,
#   '2022-05-03 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (8364,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.7,
#   '2022-05-08 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8365,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.26,
#   '2022-05-13 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (8366,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.95,
#   '2022-05-04 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (8367,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.63,
#   '2022-05-19 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (8368,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.18,
#   '2022-05-03 21:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (8369,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-09 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (8370,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-06 06:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (8371,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-08 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (8372,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-04 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
# ...
#  (9052,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.57,
#   '2022-05-09 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (9053,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.47,
#   '2022-05-06 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (9054,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.32,
#   '2022-05-08 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (9055,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-07 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (9056,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.5,
#   '2022-04-18 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (9057,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.68,
#   '2022-05-02 09:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.829495,
#   -71.417457,
#   'POINT(41.829495 1)'),
#  (9058,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.31,
#   '2022-05-15 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (9059,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.54,
#   '2022-05-09 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (9060,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.7,
#   '2022-05-08 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (9061,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.4,
#   '2022-04-30 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (9062,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.11,
#   '2022-05-19 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (9063,
#   'HARRINGTON BCH',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.15,
#   '2022-05-15 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   43.4981,
#   -87.81,
#   'POINT(43.4981 1)'),
#  (9064,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   0.3,
#   '2022-05-07 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (9065,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.6,
#   '2022-05-03 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (9066,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.31,
#   '2022-05-18 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (9067,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   1.09,
#   '2022-05-05 16:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.76988,
#   -71.428489,
#   'POINT(41.76988 1)'),
#  (9068,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.24,
#   '2022-05-17 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (9069,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-05 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (9070,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.78,
#   '2022-04-28 18:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (9071,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.19,
#   '2022-05-02 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (9072,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.13,
#   '2022-05-09 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (9073,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.21,
#   '2022-05-12 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (9074,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   0.5,
#   '2022-05-11 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (9075,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-04-29 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (9076,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.25,
#   '2022-05-07 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (9077,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.46,
#   '2022-05-06 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (9078,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-26 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (9079,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.4,
#   '2022-05-12 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (9080,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.95,
#   '2022-03-31 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (9081,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.2,
#   '2022-05-04 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (9082,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   1.07,
#   '2022-05-06 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (9083,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.34,
#   '2022-05-13 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (9084,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.32,
#   '2022-05-17 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (9085,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.38,
#   '2022-04-29 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (9086,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-05 06:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (9087,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.26,
#   '2022-04-22 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (9088,
#   'Seattle-10th & Welle',
#   'Seattle-Tacoma-Bellevue',
#   'US',
#   'bc',
#   1.3,
#   '2022-05-15 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   47.597222,
#   -122.319722,
#   'POINT(47.597222 1)'),
#  (9089,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.56,
#   '2022-05-04 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (9090,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-08 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (9091,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.5,
#   '2022-05-22 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (9092,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   1.05,
#   '2022-04-29 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.829495,
#   -71.417457,
#   'POINT(41.829495 1)'),
#  (9093,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.31,
#   '2022-05-11 06:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (9094,
#   'Near Road',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.62,
#   '2022-05-05 20:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.76988,
#   -71.428489,
#   'POINT(41.76988 1)'),
#  (9095,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   1.0,
#   '2022-05-10 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (9096,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.09,
#   '2022-05-04 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (9097,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.05,
#   '2022-05-08 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (9098,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.8,
#   '2022-05-06 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (9099,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   0.32,
#   '2022-04-28 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (9100,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.13,
#   '2022-05-02 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (9101,
#   'Livermore - Rincon',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.23,
#   '2022-05-11 15:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.687526,
#   -121.784217,
#   'POINT(37.687526 1)'),
#  (9102,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.53,
#   '2022-05-19 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (9103,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.12,
#   '2022-05-19 08:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (9104,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.07,
#   '2022-05-08 23:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (9105,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.22,
#   '2022-05-09 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (9106,
#   'Arden Arcade - Del P',
#   'Sacramento--Arden-Arcade--Roseville',
#   'US',
#   'bc',
#   0.0,
#   '2022-04-30 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.613804,
#   -121.368007,
#   'POINT(38.613804 1)'),
#  (9107,
#   'Portland Near Road',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.31,
#   '2022-05-17 05:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.39916,
#   -122.7455,
#   'POINT(45.39916 1)'),
#  (9108,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-06 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (9109,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-15 04:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (9110,
#   'McMillan Reservoir',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.08,
#   '2022-04-19 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   38.921848,
#   -77.013176,
#   'POINT(38.921848 1)'),
#  (9111,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.8,
#   '2022-04-28 02:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (9112,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.07,
#   '2022-05-13 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (9113,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.61,
#   '2022-05-17 13:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (9114,
#   'Howard County Near R',
#   'HOWARD',
#   'US',
#   'bc',
#   1.5,
#   '2022-05-10 01:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.143197,
#   -76.846192,
#   'POINT(39.143197 1)'),
#  (9115,
#   'Portland Humboldt Sc',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.34,
#   '2022-05-26 11:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.558081,
#   -122.670985,
#   'POINT(45.558081 1)'),
#  (9116,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.21,
#   '2022-04-17 03:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (9117,
#   'E Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.05,
#   '2022-05-08 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.840302,
#   -71.361702,
#   'POINT(41.840302 1)'),
#  (9118,
#   'MILWAUKEE COLLEGE AV',
#   'Milwaukee-Waukesha-West Allis',
#   'US',
#   'bc',
#   1.26,
#   '2022-05-11 19:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   42.93257,
#   -87.93434,
#   'POINT(42.93257 1)'),
#  (9119,
#   'Portland Cully Helen',
#   'Portland-Vancouver-Beaverton',
#   'US',
#   'bc',
#   0.19,
#   '2022-05-08 06:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   45.562203,
#   -122.575624,
#   'POINT(45.562203 1)'),
#  (9120,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.0,
#   '2022-05-25 17:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (9121,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.2,
#   '2022-04-30 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (9122,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   1.2,
#   '2022-05-08 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (9123,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.51,
#   '2022-05-21 07:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  (9124,
#   'Near Road OKC',
#   'Oklahoma City',
#   'US',
#   'bc',
#   0.7,
#   '2022-05-13 00:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   35.502968,
#   -97.577674,
#   'POINT(35.502968 1)'),
#  (9125,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-11 23:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (9126,
#   'Oakland West',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.42,
#   '2022-05-08 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.8148,
#   -122.282402,
#   'POINT(37.8148 1)'),
#  (9127,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.0,
#   '2022-04-28 12:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (9128,
#   'HU-Beltsville',
#   'Washington-Arlington-Alexandria',
#   'US',
#   'bc',
#   0.1,
#   '2022-05-08 10:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   39.055302,
#   -76.878304,
#   'POINT(39.055302 1)'),
#  (9129,
#   'San Jose - Knox Ave',
#   'San Jose-Sunnyvale-Santa Clara',
#   'US',
#   'bc',
#   0.46,
#   '2022-04-27 14:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.338202,
#   -121.849892,
#   'POINT(37.338202 1)'),
#  (9130,
#   'CCRI Providence',
#   'Providence-New Bedford-Fall River',
#   'US',
#   'bc',
#   0.22,
#   '2022-05-15 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   41.807523,
#   -71.41392,
#   'POINT(41.807523 1)'),
#  (9131,
#   'Laney College',
#   'San Francisco-Oakland-Fremont',
#   'US',
#   'bc',
#   0.9,
#   '2022-05-23 22:00:00+00:00',
#   'µg/m³',
#   'AirNow',
#   1.0,
#   37.793624,
#   -122.263376,
#   'POINT(37.793624 1)'),
#  ...]
