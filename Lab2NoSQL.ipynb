# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
from google.cloud import bigquery

# %%
# Create a "Client" object
client = bigquery.Client()

# %%
# Construct a reference to the "google_patents_research" dataset
bigquery_connection = client.dataset("google_patents_research", project="bigquery-public-data")

# %%
# API request - fetch the dataset
google_patents_dataset = client.get_dataset(bigquery_connection)

# %%
# List all the tables in the "google_patents_research" dataset
google_patents_tables = list(client.list_tables(google_patents_dataset))

# %%
# Print names of all tables in the dataset
for table in google_patents_tables:  
    print(table.table_id)
# Out:
# annotations
# annotations_202007
# annotations_202101
# annotations_202105
# annotations_202111
# annotations_202204
# annotations_grouped
# publications
# publications_201710
# publications_201802
# publications_201809
# publications_201903
# publications_201909
# publications_201912
# publications_202004
# publications_202007
# publications_202101
# publications_202105
# publications_202111
# publications_202204

# %%
# Construct a reference to the "publications_202204" table
table_connection = google_patents_dataset.table("publications_202204")




# API request - fetch the table
table_publications_202204 = client.get_table(table_connection)

# %%
# Preview the first five lines of the "international top rising terms" table
client.list_rows(table_publications_202204, max_results=5).to_dataframe()
# Out:
#   publication_number                                              title  \
# 0   WO-2009067033-A2  A crystallographic model of the binding site a...
# 1   WO-2015166045-A2  The application of rescap to attenuate and pre...
# 2   WO-2021181100-A1  Compositions and methods for inducing an immun...
# 3     ZA-202006479-B  Improvements in or relating to beam alignment ...
# 4     ZA-202005398-B  Managing extended 5g-s-tmsi in lte connected t...
#
#    title_translated                                           abstract  \
# 0             False  The subject matters of the invention are: a cr...
# 1             False  The present invention relates to the treatment...
# 2             False  The invention relates to a composition compris...
# 3             False
# 4             False
#
#    abstract_translated                                                cpc  \
# 0                False  [{'code': 'G16B15/30', 'inventive': True, 'fir...
# 1                False  [{'code': 'A61P25/00', 'inventive': True, 'fir...
# 2                False  [{'code': 'C12N2710/10343', 'inventive': False...
# 3                False  [{'code': 'H04B7/0897', 'inventive': True, 'fi...
# 4                False  [{'code': 'H04W76/27', 'inventive': True, 'fir...
#
#                                              cpc_low  \
# 0  [G16B15/30, G16B15/00, G16B, G16, G, G16C20/50...
# 1  [A61P25/00, A61P, A61, A, C12Y301/03001, C12Y3...
# 2  [C12N2710/10343, C12N2710/10341, C12N2710/1031...
# 3  [H04B7/0897, H04B7/0891, H04B7/08, H04B7/04, H...
# 4  [H04W76/27, H04W76/20, H04W76/00, H04W, H04, H...
#
#                                    cpc_inventive_low  \
# 0  [G16B15/30, G16B15/00, G16B, G16, G, G16C20/50...
# 1  [A61P25/00, A61P, A61, A, C12Y301/03001, C12Y3...
# 2  [C12N2710/10343, C12N2710/10341, C12N2710/1031...
# 3  [H04B7/0897, H04B7/0891, H04B7/08, H04B7/04, H...
# 4  [H04W76/27, H04W76/20, H04W76/00, H04W, H04, H...
#
#                                            top_terms similar  \
# 0  [pfk, modulator, coordinates, tables, binding ...      []
# 1  [rescap, disease, brain, neurodegenerative, pr...      []
# 2  [sars, composition, dose, vaccine, chadox1, su...      []
# 3  [relating, alignment, electronically steered, ...      []
# 4  [tmsi, lte, managing extended, managing, exten...      []
#
#                                                 url       country  \
# 0  https://patents.google.com/patent/WO2009067033A2    WIPO (PCT)
# 1  https://patents.google.com/patent/WO2015166045A2    WIPO (PCT)
# 2  https://patents.google.com/patent/WO2021181100A1    WIPO (PCT)
# 3    https://patents.google.com/patent/ZA202006479B  South Africa
# 4    https://patents.google.com/patent/ZA202005398B  South Africa
#
#                              publication_description cited_by  \
# 0  International application publshed with declar...       []
# 1  International application publshed with declar...       []
# 2  International application published with inter...       []
# 3                                     Granted patent       []
# 4                                     Granted patent       []
#
#                                         embedding_v1
# 0  [0.13142297, -0.22401766, -0.051257387, -0.145...
# 1  [-0.17739123, -0.15348703, -0.0836166, -0.0850...
# 2  [0.053326584, 0.030189348, 0.10093831, -0.1294...
# 3  [0.015821163, 0.0035525584, -0.27819073, -0.05...
# 4  [0.052048348, -0.094614774, -0.16915298, -0.11...

# %%
publications_202204DataFrame=client.list_rows(table_publications_202204, max_results=5).to_dataframe()

# %%
type(publications_202204DataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
publications_202204DataFrame.head(5)
# Out:
#   publication_number                                              title  \
# 0   WO-2009067033-A2  A crystallographic model of the binding site a...
# 1   WO-2015166045-A2  The application of rescap to attenuate and pre...
# 2   WO-2021181100-A1  Compositions and methods for inducing an immun...
# 3     ZA-202006479-B  Improvements in or relating to beam alignment ...
# 4     ZA-202005398-B  Managing extended 5g-s-tmsi in lte connected t...
#
#    title_translated                                           abstract  \
# 0             False  The subject matters of the invention are: a cr...
# 1             False  The present invention relates to the treatment...
# 2             False  The invention relates to a composition compris...
# 3             False
# 4             False
#
#    abstract_translated                                                cpc  \
# 0                False  [{'code': 'G16B15/30', 'inventive': True, 'fir...
# 1                False  [{'code': 'A61P25/00', 'inventive': True, 'fir...
# 2                False  [{'code': 'C12N2710/10343', 'inventive': False...
# 3                False  [{'code': 'H04B7/0897', 'inventive': True, 'fi...
# 4                False  [{'code': 'H04W76/27', 'inventive': True, 'fir...
#
#                                              cpc_low  \
# 0  [G16B15/30, G16B15/00, G16B, G16, G, G16C20/50...
# 1  [A61P25/00, A61P, A61, A, C12Y301/03001, C12Y3...
# 2  [C12N2710/10343, C12N2710/10341, C12N2710/1031...
# 3  [H04B7/0897, H04B7/0891, H04B7/08, H04B7/04, H...
# 4  [H04W76/27, H04W76/20, H04W76/00, H04W, H04, H...
#
#                                    cpc_inventive_low  \
# 0  [G16B15/30, G16B15/00, G16B, G16, G, G16C20/50...
# 1  [A61P25/00, A61P, A61, A, C12Y301/03001, C12Y3...
# 2  [C12N2710/10343, C12N2710/10341, C12N2710/1031...
# 3  [H04B7/0897, H04B7/0891, H04B7/08, H04B7/04, H...
# 4  [H04W76/27, H04W76/20, H04W76/00, H04W, H04, H...
#
#                                            top_terms similar  \
# 0  [pfk, modulator, coordinates, tables, binding ...      []
# 1  [rescap, disease, brain, neurodegenerative, pr...      []
# 2  [sars, composition, dose, vaccine, chadox1, su...      []
# 3  [relating, alignment, electronically steered, ...      []
# 4  [tmsi, lte, managing extended, managing, exten...      []
#
#                                                 url       country  \
# 0  https://patents.google.com/patent/WO2009067033A2    WIPO (PCT)
# 1  https://patents.google.com/patent/WO2015166045A2    WIPO (PCT)
# 2  https://patents.google.com/patent/WO2021181100A1    WIPO (PCT)
# 3    https://patents.google.com/patent/ZA202006479B  South Africa
# 4    https://patents.google.com/patent/ZA202005398B  South Africa
#
#                              publication_description cited_by  \
# 0  International application publshed with declar...       []
# 1  International application publshed with declar...       []
# 2  International application published with inter...       []
# 3                                     Granted patent       []
# 4                                     Granted patent       []
#
#                                         embedding_v1
# 0  [0.13142297, -0.22401766, -0.051257387, -0.145...
# 1  [-0.17739123, -0.15348703, -0.0836166, -0.0850...
# 2  [0.053326584, 0.030189348, 0.10093831, -0.1294...
# 3  [0.015821163, 0.0035525584, -0.27819073, -0.05...
# 4  [0.052048348, -0.094614774, -0.16915298, -0.11...

# %%
publications_202204DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   publication_number       5 non-null      object
#  1   title                    5 non-null      object
#  2   title_translated         5 non-null      boolean
#  3   abstract                 5 non-null      object
#  4   abstract_translated      5 non-null      boolean
#  5   cpc                      5 non-null      object
#  6   cpc_low                  5 non-null      object
#  7   cpc_inventive_low        5 non-null      object
#  8   top_terms                5 non-null      object
#  9   similar                  5 non-null      object
#  10  url                      5 non-null      object
#  11  country                  5 non-null      object
#  12  publication_description  5 non-null      object
#  13  cited_by                 5 non-null      object
#  14  embedding_v1             5 non-null      object
# dtypes: boolean(2), object(13)
# memory usage: 668.0+ bytes

# %% [markdown]
# ## Lets embed all the code in a try statement
#
# ### in real settings it is always advisable to embed queries to external services within try statements to manage potential errors.

# %%
try:
    client = bigquery.Client()
    bigquery_connection = client.dataset("google_patents_research", project="bigquery-public-data")
    google_patents_dataset = client.get_dataset(bigquery_connection)
    table_connection = google_patents_dataset.table("publications_202204")
    table_publications_202204 = client.get_table(table_connection)
    publications_202204DataFrame=client.list_rows(table_publications_202204, max_results=50000).to_dataframe()

except:
    print("unable to peform the operation")

# %%
publications_202204DataFrame.sample(10)
# Out:
#       publication_number                                              title  \
# 7778    WO-2020073743-A1  Audio detection method and apparatus, and devi...
# 30069   WO-2017134094-A1  Urethral devices for treatment of pathological...
# 6590    WO-2018071358-A1  Antibacterial agents against d,d- and l,d-tran...
# 2769    WO-2021220140-A1  Materials and methods for treating juvenile id...
# 17181        ZA-942204-B  Gripping arm for a rock drilling equipment or ...
# 24605   WO-2016142923-A1  Hexabenzocoronene-based compound for organic p...
# 18698     WO-03089201-A1  Electric device comprising an electric power e...
# 48600   WO-2015063053-A1  Device for transmitting a deflection movement,...
# 36134   WO-2016129735-A1            Spring structure of pumping-type vessel
# 26133   WO-2017144590-A1    Biocatalyst for manufacturing ethanol from corn
#
#        title_translated                                           abstract  \
# 7778              False  An audio detection method and apparatus, and a...
# 30069             False  A newly identified problem with conventional t...
# 6590              False  Antibacterial agents against D,D- and L,D-tran...
# 2769              False  The present invention relates to compositions ...
# 17181             False
# 24605             False  The invention relates to a hexabenzocoronene-b...
# 18698             False  The invention relates to an electric device, i...
# 48600             False  The invention relates to a device for transmit...
# 36134             False  The present invention relates to a spring stru...
# 26133             False  The invention relates to a biocatalyst for man...
#
#        abstract_translated                                                cpc  \
# 7778                 False  [{'code': 'G10L25/18', 'inventive': True, 'fir...
# 30069                False  [{'code': 'A61P7/12', 'inventive': True, 'firs...
# 6590                 False  [{'code': 'A61P31/06', 'inventive': True, 'fir...
# 2769                 False  [{'code': 'C07K16/241', 'inventive': True, 'fi...
# 17181                False  [{'code': 'E21B19/14', 'inventive': True, 'fir...
# 24605                False  [{'code': 'H01L51/0056', 'inventive': True, 'f...
# 18698                False  [{'code': 'B26B19/40', 'inventive': True, 'fir...
# 48600                False  [{'code': 'A61B1/0125', 'inventive': True, 'fi...
# 36134                False  [{'code': 'A45D2200/056', 'inventive': False, ...
# 26133                False  [{'code': 'C12N1/145', 'inventive': True, 'fir...
#
#                                                  cpc_low  \
# 7778   [G10L25/18, G10L25/03, G10L25/00, G10L, G10, G...
# 30069  [A61P7/12, A61P7/00, A61P, A61, A, A61P43/00, ...
# 6590   [A61P31/06, A61P31/04, A61P31/00, A61P, A61, A...
# 2769   [C07K16/241, C07K16/24, C07K16/18, C07K16/00, ...
# 17181               [E21B19/14, E21B19/00, E21B, E21, E]
# 24605  [H01L51/0056, H01L51/0052, H01L51/005, H01L51/...
# 18698    [B26B19/40, B26B19/38, B26B19/00, B26B, B26, B]
# 48600  [A61B1/0125, A61B1/012, A61B1/00, A61B, A61, A...
# 36134  [A45D2200/056, A45D2200/054, A45D2200/05, A45D...
# 26133  [C12N1/145, C12N1/14, C12N1/00, C12N, C12, C, ...
#
#                                        cpc_inventive_low  \
# 7778   [G10L25/18, G10L25/03, G10L25/00, G10L, G10, G...
# 30069  [A61P7/12, A61P7/00, A61P, A61, A, A61P43/00, ...
# 6590   [A61P31/06, A61P31/04, A61P31/00, A61P, A61, A...
# 2769   [C07K16/241, C07K16/24, C07K16/18, C07K16/00, ...
# 17181               [E21B19/14, E21B19/00, E21B, E21, E]
# 24605  [H01L51/0056, H01L51/0052, H01L51/005, H01L51/...
# 18698    [B26B19/40, B26B19/38, B26B19/00, B26B, B26, B]
# 48600  [A61B1/0125, A61B1/012, A61B1/00, A61B, A61, A...
# 36134  [A45D2200/056, A45D2200/054, A45D2200/05, A45D...
# 26133  [C12N1/145, C12N1/14, C12N1/00, C12N, C12, C, ...
#
#                                                top_terms  \
# 7778   [data, voice, audio, detection, audio file, do...
# 30069  [buffer, suppository, acid, tris, agent, ureth...
# 6590   [compound, alkyl, formula, transpeptidases, hy...
# 2769   [antibody, tnf, jia, amino acid, pediatric pat...
# 17181  [cartridge, rods, drilling equipment, gripping...
# 24605  [formula, compound, inclusive, polymer, obtain...
# 18698  [liquid, electrical, switch, switching, valve,...
# 48600  [control, base, channel, head, rod, deflection...
# 36134  [elastic, pumping, spring, support, container,...
# 26133  [biocatalyst, ethanol, fermentation, strain, s...
#
#                                                  similar  \
# 7778   [{'publication_number': 'WO-2020073743-A1', 'a...
# 30069  [{'publication_number': 'DE-69720985-T2', 'app...
# 6590   [{'publication_number': 'JP-6854861-B2', 'appl...
# 2769   [{'publication_number': 'US-2003049725-A1', 'a...
# 17181  [{'publication_number': 'IL-100254-D0', 'appli...
# 24605  [{'publication_number': 'EP-3268410-A1', 'appl...
# 18698  [{'publication_number': 'EP-0088298-B1', 'appl...
# 48600  [{'publication_number': 'EP-3062681-B1', 'appl...
# 36134  [{'publication_number': 'WO-2016129735-A1', 'a...
# 26133  [{'publication_number': 'RU-2560424-C2', 'appl...
#
#                                                     url       country  \
# 7778   https://patents.google.com/patent/WO2020073743A1    WIPO (PCT)
# 30069  https://patents.google.com/patent/WO2017134094A1    WIPO (PCT)
# 6590   https://patents.google.com/patent/WO2018071358A1    WIPO (PCT)
# 2769   https://patents.google.com/patent/WO2021220140A1    WIPO (PCT)
# 17181       https://patents.google.com/patent/ZA942204B  South Africa
# 24605  https://patents.google.com/patent/WO2016142923A1    WIPO (PCT)
# 18698  https://patents.google.com/patent/WO2003089201A1    WIPO (PCT)
# 48600  https://patents.google.com/patent/WO2015063053A1    WIPO (PCT)
# 36134  https://patents.google.com/patent/WO2016129735A1    WIPO (PCT)
# 26133  https://patents.google.com/patent/WO2017144590A1    WIPO (PCT)
#
#                                  publication_description  \
# 7778   International application published with inter...
# 30069  International application published with inter...
# 6590   International application published with inter...
# 2769   International application published with inter...
# 17181                                     Granted patent
# 24605  International application published with inter...
# 18698  International application published with inter...
# 48600  International application published with inter...
# 36134  International application published with inter...
# 26133  International application published with inter...
#
#                                                 cited_by  \
# 7778                                                  []
# 30069  [{'publication_number': 'US-11246693-B2', 'app...
# 6590   [{'publication_number': 'US-11084833-B2', 'app...
# 2769                                                  []
# 17181                                                 []
# 24605                                                 []
# 18698  [{'publication_number': 'US-8028708-B2', 'appl...
# 48600  [{'publication_number': 'JP-2018518276-A', 'ap...
# 36134                                                 []
# 26133  [{'publication_number': 'CN-109136100-A', 'app...
#
#                                             embedding_v1
# 7778   [-0.14470692, -0.22377051, 0.06999556, 0.12454...
# 30069  [-0.085395455, -0.110174276, 0.09619526, 0.058...
# 6590   [0.17421661, -0.07598509, -0.08074686, -0.0326...
# 2769   [0.17565295, 0.06278033, 0.10556719, -0.021528...
# 17181  [0.18349831, -0.12648381, -0.19096655, -0.0788...
# 24605  [-0.030119535, -0.15725559, -0.0007797125, -0....
# 18698  [-0.00059390685, -0.009840116, -0.048414547, -...
# 48600  [0.032598518, -0.1185851, -0.020260468, -0.036...
# 36134  [0.10976584, -0.28398046, -0.13857378, -0.0210...
# 26133  [-0.009614051, -0.14287186, -0.070451126, 0.01...
